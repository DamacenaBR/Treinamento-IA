# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9672 sha256=837a2d1942cb4d191eb1adab89a8068c8f374fbf0e26669775fd90d872d1f41b
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
import pandas as pd
import wget
from zipfile import ZipFile

# %%
url = 'http://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/DFP/DADOS/'
pathout = '/content/balanco/'
pathoutcsv = '/content/csv/'
anoInicial = 2020

# %%
arquivos = []
for ano in range(anoInicial, 2021):
    arquivos.append(f'dfp_cia_aberta_{ano}.zip')

# %%
arquivos
# Out:
# ['dfp_cia_aberta_2020.zip']

# %%
#baixar os arquivos de balanço
for arq in arquivos:
    wget.download(url+arq, out=pathout)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-6-a33723d4456c> in <module>()
#       1 #baixar os arquivos de balanço
#       2 for arq in arquivos:
# ----> 3     wget.download(url+arq, out=pathout)
#
# /usr/local/lib/python3.7/dist-packages/wget.py in download(url, out, bar)
#     504     # get filename for temp file in current directory
#     505     prefix = detect_filename(url, out)
# --> 506     (fd, tmpfile) = tempfile.mkstemp(".tmp", prefix=prefix, dir=".")
#     507     os.close(fd)
#     508     os.unlink(tmpfile)
#
# /usr/lib/python3.7/tempfile.py in mkstemp(suffix, prefix, dir, text)
#     477         flags = _bin_openflags
#     478
# --> 479     return _mkstemp_inner(dir, prefix, suffix, flags, output_type)
#     480
#     481
#
# /usr/lib/python3.7/tempfile.py in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     395         file = _os.path.join(dir, pre + name + suf)
#     396         try:
# --> 397             fd = _os.open(file, flags, 0o600)
#     398         except FileExistsError:
#     399             continue    # try again
#
# NotADirectoryError: [Errno 20] Not a directory: '/content/balanco/oj4v4ao_.tmp'

# %%
#extrair os arquivos zipados
for arq in arquivos:
    ZipFile(pathout + arq, 'r').extractall(pathoutcsv)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-7-8c1e169c808d> in <module>()
#       1 #extrair os arquivos zipados
#       2 for arq in arquivos:
# ----> 3     ZipFile(pathout + arq, 'r').extractall(pathoutcsv)
#
# /usr/lib/python3.7/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1238             while True:
#    1239                 try:
# -> 1240                     self.fp = io.open(file, filemode)
#    1241                 except OSError:
#    1242                     if filemode in modeDict:
#
# NotADirectoryError: [Errno 20] Not a directory: '/content/balanco/dfp_cia_aberta_2020.zip'

# %%
#ler DRE (demostração de resultados do exercício)
data = pd.DataFrame()
for ano in range(anoInicial,2021):
    data = pd.concat([data, pd.read_csv(pathoutcsv+f'dfp_cia_aberta_DRE_con_{ano}.csv', sep=';', decimal=',', encoding='ISO-8859-1')])

# %%
data = data[data['DS_CONTA'].str.contains('Lucro') & data['DS_CONTA'].str.contains('Prejuízo') & data['DS_CONTA'].str.contains('Consolidado')]
data = data[data['ORDEM_EXERC'] == 'ÚLTIMO']

# %%
data = data.drop(columns=['CNPJ_CIA', 'DT_REFER', 'VERSAO', 'CD_CVM', 'GRUPO_DFP', 'MOEDA', 'ESCALA_MOEDA',
                          'CD_CONTA', 'ST_CONTA_FIXA'])

# %%
stock = data[data['DENOM_CIA'] == 'BCO BRASIL S.A.']
stock

# %%
ll = []
for i in stock['VL_CONTA']:
    if(float(i) != 0):
        ll.append(float(i))

# %%
lucrodf = pd.DataFrame(ll,columns=['lucro'])

# %%
lucrodf
# Out:
#         lucro
# 0  13292883.0
